# %% [markdown]
# # Introduction
# ## Introduction
# ### Introduction
# #### Introduction
# ##### Introduction
# ###### Introduction

# %% [markdown]
# *Where* there is a **will** there is a ***way***.

# %% [markdown]
# ## The `range()` function
#
# - item1
# - item2
# - item3
#     - item 3.1
#     - item 3.2
#     - item 3.3

# %%
print("Good morning\n"*10)
# Out:
# Good morning
# Good morning
# Good morning
# Good morning
# Good morning
# Good morning
# Good morning
# Good morning
# Good morning
# Good morning

# %%
print("Hello, World!")
# Out:
# Hello, World!
